# %% [markdown]
# # **Античное наследие на карте современной Турции: карта греческих и римских исторических памятников**

# %% [markdown]
# Исследовательский вопрос:
#
# Как распределены античные памятники на территории современной Турции, какие пространственные закономерности можно выявить через их расположение на интерактивной карте?

# %% [markdown]
# **Установка необходимых библиотек**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster, HeatMap

# %% [markdown]
# **Загрузка и первичный просмотр данных**

# %%
df = pd.read_csv('AncientSitesinTurkey.csv')

print('Размер таблицы (количество строк и столбцов):', df.shape)
print(f'Наименования столбцов в таблице: {df.columns.tolist()}')

df.head()
# Out:
# Размер таблицы (количество строк и столбцов): (375, 10)
# Наименования столбцов в таблице: ['Unnamed: 0', 'Name', 'Type', 'Link', 'Latitude', 'Longitude', 'ImageUrl', 'Description', 'LatDec', 'LongDec']
#    Unnamed: 0                 Name   Type  \
# 0           0  Abydos (Hellespont)  Greek
# 1           1             Acharaca  Greek
# 2           2   Achilleion (Troad)  Greek
# 3           3             Acrassus  Greek
# 4           4      Adada (Pisidia)  Greek
#
#                                                 Link    Latitude   Longitude  \
# 0  https://en.wikipedia.org//wiki/Abydos_(Hellesp...  40°11′43″N  26°24′18″E
# 1            https://en.wikipedia.org//wiki/Acharaca     37°54′N     28°06′E
# 2  https://en.wikipedia.org//wiki/Achilleion_(Troad)  39°54′54″N    26°9′9″E
# 3            https://en.wikipedia.org//wiki/Acrassus         NaN         NaN
# 4     https://en.wikipedia.org//wiki/Adada_(Pisidia)  37°34′31″N  30°58′59″E
#
#                                             ImageUrl  \
# 0  https://upload.wikimedia.org/wikipedia/commons...
# 1  https://upload.wikimedia.org/wikipedia/commons...
# 2  https://upload.wikimedia.org/wikipedia/commons...
# 3                                                NaN
# 4  https://upload.wikimedia.org/wikipedia/commons...
#
#                                          Description     LatDec    LongDec
# 0  Abydos (Ancient Greek: Ἄβυδος, Latin: Abydus) ...  40.195278  26.405000
# 1  Acharaca (Ancient Greek: Ἀχάρακα) was a villag...  37.900000  28.100000
# 2  Achilleion (Ancient Greek: Ἀχίλλειον, romanize...  39.915000  26.152500
# 3  Acrassus or Akrassos (Ancient Greek: Ἄκρασος) ...        NaN        NaN
# 4  Adada is an ancient city and archaeological si...  37.575278  30.983056

# %% [markdown]
# **Первичный анализ структуры датасета**

# %%
print('\nТипы данных:')
print(df.dtypes)

print('\nКоличество пропусков:')
print(df.isna().sum())

main_columns = ['Name', 'Type', 'Link', 'Latitude', 'Longitude', 'LatDec', 'LongDec', 'ImageUrl', 'Description']

print('\nКоличество уникальных значений в основных столбцах:')
print(df[main_columns].nunique())

print('\nРаспределение объектов по Type (принадлежности исторического памятника к греческому или римскому происхождению):')
print(df['Type'].value_counts())

missing_coords = df[['LatDec', 'LongDec']].isna().any(axis=1).sum()

print('\nКраткий вывод:')
print(f'Для создания карты подойдут не все памятники, потому что у {missing_coords} из них отсутствуют координаты.')
# Out:
# Типы данных:
# Unnamed: 0       int64
# Name            object
# Type            object
# Link            object
# Latitude        object
# Longitude       object
# ImageUrl        object
# Description     object
# LatDec         float64
# LongDec        float64
# dtype: object
#
# Количество пропусков:
# Unnamed: 0      0
# Name            0
# Type            0
# Link            0
# Latitude       43
# Longitude      43
# ImageUrl       63
# Description     0
# LatDec         43
# LongDec        43
# dtype: int64
#
# Количество уникальных значений в основных столбцах:
# Name           375
# Type             3
# Link           375
# Latitude       329
# Longitude      331
# LatDec         324
# LongDec        329
# ImageUrl       194
# Description    354
# dtype: int64
#
# Распределение объектов по Type (принадлежности исторического памятника к греческому или римскому происхождению):
# Type
# Greek          278
# Greek/Roman     55
# Roman           42
# Name: count, dtype: int64
#
# Краткий вывод:
# Для создания карты подойдут не все памятники, потому что у 43 из них отсутствуют координаты.

# %% [markdown]
# **Очистка данных для построения карты**
#
# В датасете, как было выяснено при выполнении предыдущего действия, присутствуют лакуны в столбцах с геоданными. Следовательно, они не будут задействованы при создании карты, и логичным шагом будет очистить датасет от этих пробелов.

# %%
print('Пропуски в координатах:')
print(df[['LatDec', 'LongDec']].isna().sum())

df_map = df.dropna(subset=['LatDec', 'LongDec']).copy()

df_map = df_map.rename(columns={
    'LatDec': 'lat',
    'LongDec': 'lon'
})

df_map['lat'] = pd.to_numeric(df_map['lat'])
df_map['lon'] = pd.to_numeric(df_map['lon'])

print('\nТипы данных после очистки:')
print(df_map[['lat', 'lon']].dtypes)

print('\nКоличество памятников с координатами (после очистки):', len(df_map))
# Out:
# Пропуски в координатах:
# LatDec     43
# LongDec    43
# dtype: int64
#
# Типы данных после очистки:
# lat    float64
# lon    float64
# dtype: object
#
# Количество памятников с координатами (после очистки): 332

# %% [markdown]
# **Отбор нужных столбцов**
#
# Здесь нам нужно сделать таблицу проще и понятнее для работы, оставив только необходимые данные из датасета.

# %%
columns_project = ['Name', 'Type', 'Link', 'Description', 'ImageUrl', 'lat', 'lon']

df_clear = df_map[columns_project].copy()

print('Размер чистой таблицы:', df_clear.shape)
print('Столбцы чистой таблицы:')
print(df_clear.columns.tolist())

df_clear.head()
# Out:
# Размер чистой таблицы: (332, 7)
# Столбцы чистой таблицы:
# ['Name', 'Type', 'Link', 'Description', 'ImageUrl', 'lat', 'lon']
#                   Name         Type  \
# 0  Abydos (Hellespont)        Greek
# 1             Acharaca        Greek
# 2   Achilleion (Troad)        Greek
# 4      Adada (Pisidia)        Greek
# 5             Adıyaman  Greek/Roman
#
#                                                 Link  \
# 0  https://en.wikipedia.org//wiki/Abydos_(Hellesp...
# 1            https://en.wikipedia.org//wiki/Acharaca
# 2  https://en.wikipedia.org//wiki/Achilleion_(Troad)
# 4     https://en.wikipedia.org//wiki/Adada_(Pisidia)
# 5       https://en.wikipedia.org//wiki/Ad%C4%B1yaman
#
#                                          Description  \
# 0  Abydos (Ancient Greek: Ἄβυδος, Latin: Abydus) ...
# 1  Acharaca (Ancient Greek: Ἀχάρακα) was a villag...
# 2  Achilleion (Ancient Greek: Ἀχίλλειον, romanize...
# 4  Adada is an ancient city and archaeological si...
# 5                                                 \n
#
#                                             ImageUrl        lat        lon
# 0  https://upload.wikimedia.org/wikipedia/commons...  40.195278  26.405000
# 1  https://upload.wikimedia.org/wikipedia/commons...  37.900000  28.100000
# 2  https://upload.wikimedia.org/wikipedia/commons...  39.915000  26.152500
# 4  https://upload.wikimedia.org/wikipedia/commons...  37.575278  30.983056
# 5  https://upload.wikimedia.org/wikipedia/commons...  37.763889  38.277778

# %% [markdown]
# **Количественный анализ памятников каждого типа**
#
# На данном этапе мы строим диаграмму для наглядного оформления количественного соотношения греческих, греко-римских и римских древних памятников в датасете.

# %%
type_counts = df_clear['Type'].value_counts()

print('Количество городов каждого типа:')
print(type_counts)
print()

plt.figure(figsize=(7, 5))
type_counts.plot(kind='bar')
plt.title('Распределение античных городов по типу')
plt.xlabel('Тип города')
plt.ylabel('Количество городов')
plt.xticks(rotation=0)
plt.show()

main_type = type_counts.idxmax()
main_count = type_counts.max()


print(f'\nБольше всего в датасете памятников типа {main_type}: {main_count}.')
print('Значит, на территории современной Турции преобладает греческое историческое наследие.')
print('Римские и смешанные греко-римские памятники тоже представлены, но их, как видно, кратно меньше.\nПри этом, количество тех и других приблизительно одинаковое.')
# Out:
# Количество городов каждого типа:
# Type
# Greek          252
# Greek/Roman     49
# Roman           31
# Name: count, dtype: int64
# Больше всего в датасете памятников типа Greek: 252.
# Значит, на территории современной Турции преобладает греческое историческое наследие.
# Римские и смешанные греко-римские памятники тоже представлены, но их, как видно, кратно меньше.
# При этом, количество тех и других приблизительно одинаковое.

# %% [markdown]
# **Создание простой карты для всех типов античных памятников**
#
# Синим цветом на карте будут обозначены греческие памятники, фиолетовым - греко-римские, а красным - римские. Также будет добавлена всплывающая информация о памятнике при взаимодействии с объектом на карте, содержащая название, происхождение объекта, краткую справку о нем и ссылку на его страницу на портале Wikipedia.

# %%
map_turkey = folium.Map(
    location=[39.0, 35.0],
    zoom_start=6,
    tiles='OpenStreetMap'
)

for index, row in df_clear.iterrows():

    if row['Type'] == 'Greek':
        color = '#1E90FF'
    elif row['Type'] == 'Roman':
        color = '#DC143C'
    elif row['Type'] == 'Greek/Roman':
        color = '#8A2BE2'
    else:
        color = '#FFFFFF'

    popup_text = f"""
    <b>{row['Name']}</b><br>
    Type: {row['Type']}<br><br>
    {row['Description']}<br><br>
    <a href="{row['Link']}" target="_blank">Source</a>
    """

    folium.Marker(
        location=[row['lat'], row['lon']],
        popup=folium.Popup(popup_text, max_width=300),
        tooltip=row['Name'],
        icon=folium.DivIcon(
            html=f"""
            <div style="
                font-size: 28px;
                color: {color};
                text-shadow: 0 0 8px {color};
            ">
                🏛
            </div>
            """
        )
    ).add_to(map_turkey)

sepia_style = """
<style>
.leaflet-tile {
    filter: sepia(75%) saturate(70%) brightness(95%) contrast(90%);
}
</style>
"""

map_turkey.get_root().html.add_child(folium.Element(sepia_style))

map_turkey
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db2327731e9ac5277f65e9a435bd4e06 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;style&gt;
# .leaflet-tile {
#     filter: sepia(75%) saturate(70%) brightness(95%) contrast(90%);
# }
# &lt;/style&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db2327731e9ac5277f65e9a435bd4e06&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db2327731e9ac5277f65e9a435bd4e06 = L.map(
#                 &quot;map_db2327731e9ac5277f65e9a435bd4e06&quot;,
#                 {
#                     center: [39.0, 35.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b66b28954bb5806ed73e125c6662e99 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7b66b28954bb5806ed73e125c6662e99.addTo(map_db2327731e9ac5277f65e9a435bd4e06);
#
#
#             var marker_38e54f2540b499dfd3887bebee2b45f2 = L.marker(
#                 [40.195277777777775, 26.405],
#                 {
# }
#             ).addTo(map_db2327731e9ac5277f65e9a435bd4e06);
#
#
#             var div_icon_353c8346200548ebebf42ec3cc524842 = L.divIcon({
#   &quot;html&quot;: &quot;\n            \u003cdiv style=\&quot;\n                font-size: 28px;\n                color: #1E90FF;\n                text-shadow: 0 0 8px #1E90FF;\n            \&quot;\u003e\n                \ud83c\udfdb\n            \u003c/div\u003e\n            &quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#         var popup_379d2e8ba44502fdad9780de27fc292c = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_b09b673eae1265eeff0797bb60bfbeb1 = $(`&lt;div id=&quot;html_b09b673eae1265eeff0797bb60bfbeb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Abydos (Hellespont)&lt;/b&gt;&lt;br&gt;     Type: Greek&lt;br&gt;&lt;br&gt;     Abydos (Ancient Greek: Ἄβυδος, Latin: Abydus) was an ancient city and bishopric in Mysia.[nb 1] It was located at the Nara Burnu promontory on the Asian coast of the Hellespont (the straits of Dardanelles), opposite the ancient city of Sestos, and near the city of Çanakkale in Turkey. Abydos was founded in c. 670 BC at the most narrow point in the straits,[1] and thus was one of the main crossing points between Europe and Asia, until its replacement by the crossing between Lampsacus and Kallipolis in the 13th century,[5] and the abandonment of Abydos in the early 14th century.[2] &lt;br&gt;&lt;br&gt;     &lt;a href=&quot;https://en.wikipedia.org//wiki/Abydos_(Hellespont)&quot; target=&quot;_blank&quot;&gt;Source&lt;/a&gt;     &lt;/div&gt;`)[0];
#                 popup_379d2e8ba44502fdad9780de27fc292c.setContent(html_b09b673eae1265eeff0797bb60bfbeb1);
#
#
#
#         marker_38e54f2540b499dfd3887bebee2b45f2.bindPopup(popup_379d2e8ba44502fdad9780de27fc292c)
#         ;
#
#
#
#
#             marker_38e54f2540b499dfd3887bebee2b45f2.bindTooltip(
#                 `&lt;div&gt;
#                      Abydos (Hellespont)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_38e54f2540b499dfd3887bebee2b45f2.setIcon(div_icon_353c8346200548ebebf42ec3cc524842);
#
#
#             var marker_d7868757dd118d1d774b040e852086d4 = L.marker(
#                 [37.9, 28.1],
#                 {
# }
#             ).addTo(map_db2327731e9ac5277f65e9a435bd4e06);
#
#
#             var div_icon_3909913bf7b6b127f30baf8389e15dc1 = L.divIcon({
#   &quot;html&quot;: &quot;\n            \u003cdiv style=\&quot;\n                font-size: 28px;\n                color: #1E90FF;\n                text-shadow: 0 0 8px #1E90FF;\n            \&quot;\u003e\n                \ud83c\udfdb\n            \u003c/div\u003e\n            &quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#         var popup_74aa6c5c20d796f4478e0c90252fce8b = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_1ceb0fb888a8a35eadcc18d42fa6cdd5 = $(`&lt;div id=&quot;html_1ceb0fb888a8a35eadcc18d42fa6cdd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Acharaca&lt;/b&gt;&lt;br&gt;     Type: Greek&lt;br&gt;&lt;br&gt;     Acharaca (Ancient Greek: Ἀχάρακα) was a village of ancient Lydia, Anatolia on the road from Tralles (modern Aydın, Turkey) to Nysa on the Maeander, with a Ploutonion or a temple of Pluto, and a cave, named Charonium (Ancient Greek: Χαρώνειον άντρον), where the sick were healed under the direction of the priests.[1] There is some indication that it once bore the name Charax (Χάραξ

# %% [markdown]
# **Тепловая карта плотности объектов**
#
# С помощью тепловой карты можно проследить зоны наибольшей концентрации памятников и увидеть, в из них находится больше всего античных объектов.

# %%
import folium
from folium.plugins import HeatMap

heat_data = df_clear[['lat', 'lon']].values.tolist()

m_heat = folium.Map(
    location=[39.0, 35.0],
    zoom_start=6,
    tiles='OpenStreetMap'
)

HeatMap(heat_data, radius=15, blur=10).add_to(m_heat)

sepia_style = """
<style>
.leaflet-tile {
    filter: sepia(75%) saturate(70%) brightness(95%) contrast(90%);
}
</style>
"""

m_heat.get_root().html.add_child(folium.Element(sepia_style))

display(m_heat)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68b5261c161ced25869b63e3f0501c5c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;style&gt;
# .leaflet-tile {
#     filter: sepia(75%) saturate(70%) brightness(95%) contrast(90%);
# }
# &lt;/style&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68b5261c161ced25869b63e3f0501c5c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_68b5261c161ced25869b63e3f0501c5c = L.map(
#                 &quot;map_68b5261c161ced25869b63e3f0501c5c&quot;,
#                 {
#                     center: [39.0, 35.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7fea5fe29257f13b5a1179ed2a27300c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7fea5fe29257f13b5a1179ed2a27300c.addTo(map_68b5261c161ced25869b63e3f0501c5c);
#
#
#             var heat_map_5578c2ddb905388bfea49e5e52de7322 = L.heatLayer(
#                 [[40.195277777777775, 26.405], [37.9, 28.1], [39.915, 26.1525], [37.57527777777778, 30.98305555555556], [37.763888888888886, 38.27777777777778], [39.49777777777778, 26.9375], [40.36407222222223, 26.63083333333333], [37.64944444444444, 30.53388888888889], [38.83111111111111, 27.18861111111111], [39.2, 29.616666666666667], [38.35, 28.516666666666666], [39.751666666666665, 26.15861111111111], [37.55833333333333, 27.82361111111111], [39.234722222222224, 27.30555555555556], [41.74944444444444, 32.38638888888889], [40.65, 35.83305555555556], [36.75755555555556, 28.268894444444445], [37.263888888888886, 35.90555555555555], [36.80972222222222, 34.69944444444444], [36.24722222222222, 29.982777777777777], [36.02426944444444, 32.8026], [36.2025, 36.160555555555554], [36.8875, 30.7075], [39.575833333333335, 26.79055555555556], [36.25391666666667, 36.20516666666667], [36.20472222222222, 36.181666666666665], [36.157222222222224, 32.41555555555556], [36.55722222222222, 34.24111111111111], [36.2, 29.635], [37.06666666666667, 37.88361111111111], [38.07166666666667, 30.165555555555557], [40.37638888888889, 28.883333333333333], [37.708333333333336, 28.723611111111108], [36.15805555555556, 33.69166666666666], [36.18666666666666, 29.76388888888889], [39.2025, 27.494444444444447], [40.16944444444445, 28.6825], [37.506388888888885, 29.023055555555555], [38.045, 28.83055555555556], [36.74555555555556, 29.369444444444444], [37.18111111111111, 30.4725], [40.19972222222222, 26.542222222222225], [42.049166666666665, 35.04194444444444], [36.44194444444444, 29.87138888888889], [36.41277777777778, 35.88666666666666], [36.93888888888888, 31.172222222222224], [39.48777777777778, 26.336944444444445], [40.714444444444446, 29.92888888888889], [39.09138888888889, 26.92083333333333], [36.60444444444445, 34.08083333333334], [41.18111111111111, 40.888888888888886], [37.84222222222223, 28.80583333333333], [37.24527777777778, 35.344166666666666], [36.81111111111111, 34.70194444444445], [37.84805555555556, 27.845277777777778], [36.95527777777778, 29.58111111111111], [37.2, 27.57555555555556], [41.03361111111111, 28.733888888888888], [37.275, 27.789166666666667], [39.11666666666667, 27.183333333333334], [37.49810833333333, 27.52680833333333], [37.68333333333333, 31.73333333333333], [37.025, 37.97694444444445], [40.98333333333333, 27.516666666666666], [37.03333333333333, 27.433333333333334], [40.734722222222224, 31.6075], [36.969166666666666, 29.40694444444444], [40.18333333333333, 29.05], [41.015277777777776, 28.984722222222224], [40.589444444444446, 36.955000000000005], [36.75055555555556, 28.835833333333333], [40.6, 33.61666666666667], [36.68361111111111, 31.88583333333333], [42.01361111111111, 33.36972222222222], [40.54722222222222, 26.74083333333333], [37.5, 28.0], [40.52777777777778, 35.14055555555556], [36.574444444444445, 29.09027777777777], [41.81, 35.15888888888889], [37.12638888888889, 27.378055555555555], [37.1775, 36.1875], [39.744166666666665, 26.56638888888889], [37.0425, 27.95138888888889], [37.34916666666667, 27.68583333333333], [36.65972222222222, 31.65972222222222], [36.86666666666667, 35.483333333333334], [41.96277777777778, 34.154444444444444], [40.4325, 29.156388888888888], [38.005, 27.192777777777778], [36.65166666666666, 33.44166666666666], [38.10888888888889, 27.141666666666666], [41.9475, 34.271388888888886], [36.73166666666667, 31.975277777777777], [36.55138888888889, 29.669444444444444], [37.22888888888889, 39.755833333333335], [36.46527777777778, 34.15416666666667], [36.3766666666666

# %% [markdown]
# **Создание условных регионов современной Турции**
#
# К уже имеющемуся у нас датасету мы добавляем новый столбец, который будет обозначать, в каком регионе на территории современной Турции расположен тот или иной памятник по долготе. Для большей наглядности создаем график с количественными данными.

# %%
def assign_region(lon):
    if pd.isna(lon):
        return None
    if lon < 30:
        return 'Западная Турция (Эгейско-Мраморская зона)'
    elif lon < 38:
        return 'Центральная и южная Анатолия'
    else:
        return 'Восточная и северо-восточная Анатолия'

df_clear['Region'] = df_clear['lon'].apply(assign_region)
df_clear = df_clear.dropna(subset=['Region'])

print(df_clear['Region'].value_counts())
# Out:
# Region
# Западная Турция (Эгейско-Мраморская зона)    180
# Центральная и южная Анатолия                 140
# Восточная и северо-восточная Анатолия         12
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

region_counts = df['Region'].value_counts()
region_counts.plot(kind='bar', figsize=(10, 6), color='skyblue')
plt.title('Количество памятников по условным регионам')
plt.xlabel('Регион')
plt.ylabel('Количество объектов')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

dominant_region = region_counts.idxmax()
print(f'\nПревалирующий регион: {dominant_region} ({region_counts.max()} объектов)')
# Out:
# Превалирующий регион: Западная Турция (Эгейско-Мраморская зона) (180 объектов)

# %% [markdown]
# **Перекрёстная таблица: регион и тип объекта**
#
# В этом блоке мы сравниваем, какие именно типы памятников преобладают в каждом из выведенных ранее регионов.

# %%
cross_tab = pd.crosstab(df['Region'], df['Type'])
display(cross_tab)

print('\nАналитика типов по регионам:')
for region in cross_tab.index:
    max_type = cross_tab.loc[region].idxmax()
    print(f'{region}: преобладает тип "{max_type}"')
# Out:
# Type                                       Greek  Greek/Roman  Roman
# Region
# Восточная и северо-восточная Анатолия          9            3      0
# Западная Турция (Эгейско-Мраморская зона)    146           26      8
# Центральная и южная Анатолия                  97           20     23
# Аналитика типов по регионам:
# Восточная и северо-восточная Анатолия: преобладает тип "Greek"
# Западная Турция (Эгейско-Мраморская зона): преобладает тип "Greek"
# Центральная и южная Анатолия: преобладает тип "Greek"

# %% [markdown]
# **Итоговый вариант карты античных памятников**
#
# Теперь карта содержит слои, отображающие все виды памятников по отдельности. В pop-up окно информации добавлен регион памятника, который мы вывели ранее.

# %%
m_layers = folium.Map(
    location=[39.0, 35.0],
    zoom_start=6,
    tiles='OpenStreetMap'
)

layer_greek = folium.FeatureGroup(name='Greek')
layer_roman = folium.FeatureGroup(name='Roman')
layer_mixed = folium.FeatureGroup(name='Greek/Roman')

for index, row in df_clear.iterrows():

    if row['Type'] == 'Greek':
        color = '#1E90FF'
        layer = layer_greek
    elif row['Type'] == 'Roman':
        color = '#DC143C'
        layer = layer_roman
    elif row['Type'] == 'Greek/Roman':
        color = '#8A2BE2'
        layer = layer_mixed
    else:
        color = '#FFFFFF'
        layer = layer_greek

    popup_text = f"""
    <b>{row['Name']}</b><br>
    <b>Type:</b> {row['Type']}<br>
    <b>Region:</b> {row['Region']}<br><br>
    {row['Description']}<br><br>
    <a href="{row['Link']}" target="_blank">Source</a>
    """

    folium.Marker(
        location=[row['lat'], row['lon']],
        popup=folium.Popup(popup_text, max_width=300),
        tooltip=row['Name'],
        icon=folium.DivIcon(
            html=f"""
            <div style="
                font-size: 28px;
                color: {color};
                text-shadow: 0 0 8px {color};
            ">
                🏛
            </div>
            """
        )
    ).add_to(layer)

layer_greek.add_to(m_layers)
layer_roman.add_to(m_layers)
layer_mixed.add_to(m_layers)

folium.LayerControl().add_to(m_layers)

sepia_style = """
<style>
.leaflet-tile {
    filter: sepia(75%) saturate(70%) brightness(95%) contrast(90%);
}
</style>
"""

m_layers.get_root().html.add_child(folium.Element(sepia_style))

display(m_layers)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_620c9525db5c49dcf1da5587ab6222c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;style&gt;
# .leaflet-tile {
#     filter: sepia(75%) saturate(70%) brightness(95%) contrast(90%);
# }
# &lt;/style&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_620c9525db5c49dcf1da5587ab6222c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_620c9525db5c49dcf1da5587ab6222c8 = L.map(
#                 &quot;map_620c9525db5c49dcf1da5587ab6222c8&quot;,
#                 {
#                     center: [39.0, 35.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cfc1ca43f0cbda519f05a062a4087e86 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cfc1ca43f0cbda519f05a062a4087e86.addTo(map_620c9525db5c49dcf1da5587ab6222c8);
#
#
#             var feature_group_2fab5db11f67b0949f30cff0f8a22d9d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_103e051fa54460ca11d61ba69d282155 = L.marker(
#                 [40.195277777777775, 26.405],
#                 {
# }
#             ).addTo(feature_group_2fab5db11f67b0949f30cff0f8a22d9d);
#
#
#             var div_icon_fdc32317445b9d419fda0bb330fd54e2 = L.divIcon({
#   &quot;html&quot;: &quot;\n            \u003cdiv style=\&quot;\n                font-size: 28px;\n                color: #1E90FF;\n                text-shadow: 0 0 8px #1E90FF;\n            \&quot;\u003e\n                \ud83c\udfdb\n            \u003c/div\u003e\n            &quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#         var popup_cace7a2dda9f802f39d37f55f8b9dcf3 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_084ac7ce9c8c35e1664577df2610d4ec = $(`&lt;div id=&quot;html_084ac7ce9c8c35e1664577df2610d4ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Abydos (Hellespont)&lt;/b&gt;&lt;br&gt;     &lt;b&gt;Type:&lt;/b&gt; Greek&lt;br&gt;     &lt;b&gt;Region:&lt;/b&gt; Западная Турция (Эгейско-Мраморская зона)&lt;br&gt;&lt;br&gt;     Abydos (Ancient Greek: Ἄβυδος, Latin: Abydus) was an ancient city and bishopric in Mysia.[nb 1] It was located at the Nara Burnu promontory on the Asian coast of the Hellespont (the straits of Dardanelles), opposite the ancient city of Sestos, and near the city of Çanakkale in Turkey. Abydos was founded in c. 670 BC at the most narrow point in the straits,[1] and thus was one of the main crossing points between Europe and Asia, until its replacement by the crossing between Lampsacus and Kallipolis in the 13th century,[5] and the abandonment of Abydos in the early 14th century.[2] &lt;br&gt;&lt;br&gt;     &lt;a href=&quot;https://en.wikipedia.org//wiki/Abydos_(Hellespont)&quot; target=&quot;_blank&quot;&gt;Source&lt;/a&gt;     &lt;/div&gt;`)[0];
#                 popup_cace7a2dda9f802f39d37f55f8b9dcf3.setContent(html_084ac7ce9c8c35e1664577df2610d4ec);
#
#
#
#         marker_103e051fa54460ca11d61ba69d282155.bindPopup(popup_cace7a2dda9f802f39d37f55f8b9dcf3)
#         ;
#
#
#
#
#             marker_103e051fa54460ca11d61ba69d282155.bindTooltip(
#                 `&lt;div&gt;
#                      Abydos (Hellespont)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_103e051fa54460ca11d61ba69d282155.setIcon(div_icon_fdc32317445b9d419fda0bb330fd54e2);
#
#
#             var marker_10d7062d2550177593dee37321bc741b = L.marker(
#                 [37.9, 28.1],
#                 {
# }
#             ).addTo(feature_group_2fab5db11f67b0949f30cff0f8a22d9d);
#
#
#             var div_icon_acb3ff6094ca54401d3465726d246e3b = L.divIcon({
#   &quot;html&quot;: &quot;\n            \u003cdiv style=\&quot;\n                font-size: 28px;\n                color: #1E90FF;\n                text-shadow: 0 0 8px #1E90FF;\n            \&quot;\u003e\n                \ud83c\udfdb\n            \u003c/div\u003e\n            &quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#         var popup_b41a4e2c332c64eeb4566bf1868f5a9b = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_a5664e5d85042942c2881885fec38a06 = $(`&lt;div id=&quot;html_a5664e5d85042942c2881885fec38a06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Acharaca&lt;/b&gt;&lt;br&gt;     &lt;b&gt;Type:&lt;/b&gt; Greek&lt;br&gt;     &lt;b&gt;Region:&lt;/b&gt; Западная Турция (Эгейско-Мраморская зона)&lt;br&gt;&lt;br&gt;     Acharaca (Ancient Greek: Ἀχά

# %% [markdown]
# **Сохранение карты в HTML**

# %%
m_layers.save('antique_turkey_sites_map.html')
print('Карта успешно сохранена в файл "antique_turkey_sites_map.html"')
# Out:
# Карта успешно сохранена в файл "antique_turkey_sites_map.html"
